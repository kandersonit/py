# %%
import pandas as pd
import random 

delta_table_path = "abfss://58e80545-94b4-4bc4-80f9-c67a4bd86308@onelake.dfs.fabric.microsoft.com/8f93df74-dc46-4398-95e3-6bd1605c0a9b/Tables/SalesLine"
dt = spark.createDataFrame(delta_table_path)

print(dt)

df = dt.select("*").toPandas()

print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 import random
#       4 delta_table_path = "abfss://58e80545-94b4-4bc4-80f9-c67a4bd86308@onelake.dfs.fabric.microsoft.com/8f93df74-dc46-4398-95e3-6bd1605c0a9b/Tables/SalesLine"
# ----> 5 dt = spark.createDataFrame(delta_table_path)
#       7 print(dt)
#       9 df = dt.select("*").toPandas()
#
# NameError: name 'spark' is not defined
