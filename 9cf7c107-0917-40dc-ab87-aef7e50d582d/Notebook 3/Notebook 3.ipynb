# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
df = spark.sql("SELECT * FROM LochHouse.InventTable LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 2c0cd8ef-07b8-4e48-ac33-82ca233186b6, 3, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 38fab40c-2380-4161-b4c6-e20b7bea18bb)
