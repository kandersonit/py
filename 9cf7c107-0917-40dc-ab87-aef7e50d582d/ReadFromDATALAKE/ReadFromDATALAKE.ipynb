# %%
import pandas as pd


from pyspark.sql.types import *
from pyspark.sql import functions, Row
from decimal import Decimal
from datetime import datetime

sas = "sp=rw&st=2023-08-31T04:15:43Z&se=2023-09-14T12:15:43Z&spr=https&sv=2022-11-02&sr=c&sig=MZxsxFOGq3bDsSxwaq0FW4libWK31m9yIHvFQ773G1U%3D"
storageAccountName = "csdatalakestorage.dfs.core.windows.net"
container = "dynamics365-financeandoperations"
outputContainer = "dynamics365-financeandoperations"
abfssRoot = "abfss://" + outputContainer + "@" + storageAccountName
folder1 = "/csi-testing.sandbox.operations.dynamics.com/Entities/SupplyChain/"

#read CDM entities
df = (spark.read.format("com.microsoft.cdm")
  .option("storage", storageAccountName)
  .option("manifestPath", container + folder1 + "SalesAndMarketing/SalesAndMarketing.manifest.cdm.json")
  .option("entity", "SalesOrderLineV2Entity")
  .option("entityDefinitionModelRoot", container + folder1)
  .option("sasToken", sas)

  .load())

df.printSchema()

df.select("*").show()

#2023-08-31 04:17:37,603 INFO CDMModelCommon [Thread-240]: Path for ADLSAdapter: csdatalakestorage.dfs.core.windows.net/dynamics365-financeandoperations/csi-testing.sandbox.operations.dynamics.com/Entities/SupplyChain/SalesAndMarketing
# Out:
# StatementMeta(, 1c27107c-dcb0-4920-adf8-75ff83d6aa8f, 3, Finished, Available)
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[8], line 24
#      14 folder1 = "/csi-testing.sandbox.operations.dynamics.com/Entities/SupplyChain/"
#      16 #read CDM entities
#      17 df = (spark.read.format("com.microsoft.cdm")
#      18   .option("storage", storageAccountName)
#      19   .option("manifestPath", container + folder1 + "SalesAndMarketing/SalesAndMarketing.manifest.cdm.json")
#      20   .option("entity", "SalesOrderLineV2Entity")
#      21   .option("entityDefinitionModelRoot", container + folder1)
#      22   .option("sasToken", sas)
#      23
# ---> 24   .load())
#      26 df.printSchema()
#      28 df.select("*").show()
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/readwriter.py:184, in DataFrameReader.load(self, path, format, schema, **options)
# ...
